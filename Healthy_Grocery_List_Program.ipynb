# %%
def healthier_option(item, grocery_options):
    for key, value in grocery_options.items():
        if key in item:
            if value[1] == 'healthy':
                return None
            else:
                for healthy_key, healthy_value in grocery_options.items():
                    if healthy_value[1] == 'healthy':
                        return f"You might consider replacing {item} with a healthier option such as {healthy_key}."
total_cost = 0
grocery_list = []

while True:
    groceries = input("Choose a grocery item from grocery_options dictionary below or type 'done' to finish): ")

    if groceries.lower() == 'done':
        break
    prices = float(input(f"Enter the price of {groceries}: "))
    quantity = float(input(f"Enter the quantity of {groceries}: "))
    grocery_cost = prices * quantity
    total_cost += grocery_cost
    grocery_list.append([groceries, grocery_cost])
# Dictionary containing options and their health status

print("\nYour grocery list:",grocery_list)

for item in grocery_list:
    print(f"{item[0]} costs ${item[1]:.2f}")

# Check if total cost exceeds budget
budget = float(input("\nEnter your budget: $"))
print(f"\nTotal cost of items: ${total_cost:.2f}")
if total_cost > budget:
    print("Total cost exceeds your budget. Please remove some items.")
else:
    print("Total cost fits within your budget.")



grocery_options = {
    'fruit': [3.80, 'healthy'],
    'frozen fries': [4.45, 'not healthy'],
    'chicken': [6.25, 'healthy'],
    'spinach': [2.50, 'healthy'],
    'salmon': [9.75, 'healthy'],
    'quinoa': [4.20, 'healthy'],
    'brown rice': [3.00, 'healthy'],
    'almonds': [5.60, 'healthy'],
    'avocado': [2.75, 'healthy'],
    'yogurt': [3.25, 'healthy'],
    'oatmeal': [2.00, 'healthy'],
    'eggs': [2.50, 'healthy'],
    'whole wheat bread': [3.00, 'healthy'],
    'kale': [3.50, 'healthy'],
    'beans': [1.75, 'healthy'],
    'sweet potatoes': [2.00, 'healthy'],
    'tomatoes': [1.50, 'healthy'],
    'broccoli': [2.25, 'healthy'],
    'green tea': [2.20, 'healthy'],
    'lean beef': [7.50, 'healthy'],
    'cottage cheese': [3.80, 'healthy'],
    'turkey': [6.00, 'healthy'],
    'whole grain pasta': [2.75, 'healthy'],
    'apples': [1.80, 'healthy'],
    'berries': [4.00, 'healthy'],
    'carrots': [1.20, 'healthy'],
    'soda': [1.50, 'not healthy'],
    'potato chips': [2.75, 'not healthy'],
    'candy bars': [1.20, 'not healthy'],
    'white bread': [2.00, 'not healthy'],
    'fried chicken': [5.80, 'not healthy'],
    'ice cream': [4.50, 'not healthy'],
    'cookies': [3.25, 'not healthy'],
    'chocolate': [2.50, 'not healthy'],
    'pizza': [8.00, 'not healthy'],
    'hamburgers': [6.75, 'not healthy'],
    'hot dogs': [3.00, 'not healthy'],
    'frozen pizza': [5.50, 'not healthy'],
    'instant noodles': [1.00, 'not healthy'],
    'microwave popcorn': [2.20, 'not healthy'],
    'fried fish': [7.25, 'not healthy'],
    'processed cheese': [2.80, 'not healthy'],
    'sugary cereals': [3.50, 'not healthy'],
    'energy drinks': [2.75, 'not healthy'],
    'donuts': [1.80, 'not healthy'],
    'white rice': [1.50, 'not healthy'],
    'fried potatoes': [3.00, 'not healthy'],
    'frozen dinners': [4.25, 'not healthy'],
    'buttered popcorn': [2.50, 'not healthy']}
for item in grocery_list:
    suggestion = healthier_option(item[0], grocery_options)
    if suggestion:
        print(suggestion)
